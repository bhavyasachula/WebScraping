# %%
from bs4  import BeautifulSoup
import requests as rs
url = "https://en.wikipedia.org/wiki/List_of_the_largest_counties_in_the_United_States_by_area"

page = rs.get(url)

# %%
soup = BeautifulSoup(page.text,"html")
print(soup)

# %%
import pandas as pd
